# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport HilbertCurve
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualizing HilbertCurve in a 4x4 grid

# %%
ind = 4
arr = np.ones((ind, ind))
for i in range(ind):
    for j in range(ind):
        arr[i, j] = HilbertCurve.HilbertValue(ind, i, j)

for j in range(ind -1, -1, -1):
    print([arr[i, j] for i in range(ind)])
    print()
# Out:
# [5.0, 6.0, 9.0, 10.0]
#
# [4.0, 7.0, 8.0, 11.0]
#
# [3.0, 2.0, 13.0, 12.0]
#
# [0.0, 1.0, 14.0, 15.0]

# %% [markdown]
# ## Visualizing MotionRugs on FishData

# %%
df = pd.read_csv("..//data//fishdatashort.csv")
data = df.drop(columns = ['frame', 'id']).to_numpy().reshape(2000, 151, -1)
img = HilbertCurve.MotionRugs(data, 256, 1)
img_bw = HilbertCurve.convert_gray_scale(img)

# %% [markdown]
# Using speed as color.

# %%
fig = plt.figure(figsize = (30, 20))
plt.imshow(img_bw)
plt.axis('off')
plt.show()

# %%
img = HilbertCurve.MotionRugs(data, 256, 2)
img_bw = HilbertCurve.convert_gray_scale(img)

# %% [markdown]
# Using acelaration as color.

# %%
fig = plt.figure(figsize = (30, 20))
plt.imshow(img_bw)
plt.axis('off')
plt.show()
